# %% [markdown]
# # Illumina data-analysis
#
# The illumina data has to be spliced according to the index. This is generally done by the Basespace software.
# Each sample should be treated through the pipeline seperatly in order to obtain a profile of each sample.

# %% [markdown]
# ## Unzipping fastq and compressing to one file

# %%
# %%bash
#
# cd /media/genomics/senne/Illumina_multiplex_data2/
# gunzip -d *.fastq.gz
# Out:
# gzip: Senne2800_S19_L001_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L001_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L002_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L002_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L003_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L003_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L004_R1_001.fastq: Operation not permitted
# gzip: Senne2800_S19_L004_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L001_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L001_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L002_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L002_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L003_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L003_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L004_R1_001.fastq: Operation not permitted
# gzip: Senne47_S20_L004_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L001_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L001_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L002_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L002_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L003_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L003_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L004_R1_001.fastq: Operation not permitted
# gzip: Senne48_S21_L004_R1_001.fastq: Operation not permitted

# %%
# !pwd
# Out:
# /home/senne/nanopore

# %%
# %%bash
#
# cd /media/genomics/senne/Illumina_multiplex_data2/
#
# cat Senne48_*.fastq > 48.fastq

# %% [markdown]
# ##Converting a fastq to a fasta

# %%
# %%bash
#
# cd /home/senne/nanopore/Multiplex/Reference_sequences/SNP/9948_Illumina_0.5µM/
#
# sed -n '1~4s/^@/>/p;2~4p' 48.fastq > 48.fasta

# %% [markdown]
# ## Input

# %%
# Init
#

snpFile   = '/home/senne/nanopore/SNP/known_SNP_sequence/SNP_sequence.fasta'  # 
readFile  = '/home/senne/nanopore/Multiplex/Reference_sequences/SNP/9948_Illumina_0.5µM/48.fasta' # each sample has a seperate fasta file
resultDir = '/home/senne/nanopore/Multiplex/Reference_sequences/SNP/9948_Illumina_0.5µM/'
fastq_file_name= '/home/senne/nanopore/Multiplex/Reference_sequence/SNP/Male_Promega/PromegaM.fastq' # Eigenlijk niet nodig hier. 
bwa       = '/opt/tools/bwa-0.7.15'            # v0.7.5
samtools  = '/opt/tools/samtools-1.3.1' # v1.3.1
bcftools  = '/opt/tools/bcftools-1.3.1' # v1.3.1

# Check
# !ls {snpFile}
print('Number of SNPs in reference file:')
# !grep -c ">" {snpFile}
# Out:
# /home/senne/nanopore/SNP/known_SNP_sequence/SNP_sequence.fasta
# Number of SNPs in reference file:
# 52

# %% [markdown]
# ##Mapping using BWA

# %%
# Map reads to reference sequences
#

# Build index of the references
# !{bwa} index {snpFile}

# Map reads
# !{bwa} mem -a {snpFile} {readFile} > {resultDir}/48.sam
# Out:
# [bwa_index] Pack FASTA... 0.00 sec
# [bwa_index] Construct BWT for the packed sequence...
# [bwa_index] 0.00 seconds elapse.
# [bwa_index] Update BWT... 0.00 sec
# [bwa_index] Pack forward-only FASTA... 0.00 sec
# [bwa_index] Construct SA from BWT and Occ... 0.00 sec
# [main] Version: 0.7.15-r1140
# [main] CMD: /opt/tools/bwa-0.7.15 index /home/senne/nanopore/SNP/known_SNP_sequence/SNP_sequence.fasta
# [main] Real time: 0.017 sec; CPU: 0.006 sec
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 148786 sequences (10000010 bp)...
# [M::process] read 149412 sequences (10000139 bp)...
# [M::mem_process_seqs] Processed 148786 reads in 3.256 CPU sec, 3.154 real sec
# [M::process] read 149482 sequences (10000102 bp)...
# [M::mem_process_seqs] Processed 149412 reads in 3.655 CPU sec, 3.249 real sec
# [M::process] read 149622 sequences (10000029 bp)...
# [M::mem_process_seqs] Processed 149482 reads in 3.963 CPU sec, 3.610 real sec
# [M::process] read 149542 sequences (10000057 bp)...
# [M::mem_process_seqs] Processed 149622 reads in 3.720 CPU sec, 3.350 real sec
# [M::process] read 149404 sequences (10000081 bp)...
# [M::mem_process_seqs] Processed 149542 reads in 3.484 CPU sec, 3.249 real sec
# [M::process] read 149062 sequences (10000030 bp)...
# [M::mem_process_seqs] Processed 149404 reads in 3.660 CPU sec, 3.245 real sec
# [M::process] read 148484 sequences (10000043 bp)...
# [M::mem_process_seqs] Processed 149062 reads in 3.564 CPU sec, 3.383 real sec
# [M::process] read 149286 sequences (10000047 bp)...
# [M::mem_process_seqs] Processed 148484 reads in 3.650 CPU sec, 3.247 real sec
# [M::process] read 149344 sequences (10000030 bp)...
# [M::mem_process_seqs] Processed 149286 reads in 4.046 CPU sec, 3.761 real sec
# [M::process] read 149502 sequences (10000005 bp)...
# [M::mem_process_seqs] Processed 149344 reads in 3.461 CPU sec, 3.253 real sec
# [M::process] read 149498 sequences (10000042 bp)...
# [M::mem_process_seqs] Processed 149502 reads in 3.328 CPU sec, 3.142 real sec
# [M::process] read 149304 sequences (10000032 bp)...
# [M::mem_process_seqs] Processed 149498 reads in 3.913 CPU sec, 3.624 real sec
# [M::process] read 148986 sequences (10000127 bp)...
# [M::mem_process_seqs] Processed 149304 reads in 3.899 CPU sec, 3.622 real sec
# [M::process] read 148524 sequences (10000039 bp)...
# [M::mem_process_seqs] Processed 148986 reads in 3.517 CPU sec, 3.205 real sec
# [M::process] read 148668 sequences (10000129 bp)...
# [M::mem_process_seqs] Processed 148524 reads in 3.381 CPU sec, 3.210 real sec
# [M::process] read 149172 sequences (10000090 bp)...
# [M::mem_process_seqs] Processed 148668 reads in 3.653 CPU sec, 3.290 real sec
# [M::process] read 149446 sequences (10000135 bp)...
# [M::mem_process_seqs] Processed 149172 reads in 3.407 CPU sec, 3.223 real sec
# [M::process] read 149454 sequences (10000047 bp)...
# [M::mem_process_seqs] Processed 149446 reads in 3.612 CPU sec, 3.226 real sec
# [M::process] read 149326 sequences (10000065 bp)...
# [M::mem_process_seqs] Processed 149454 reads in 3.320 CPU sec, 3.130 real sec
# [M::process] read 149012 sequences (10000102 bp)...
# [M::mem_process_seqs] Processed 149326 reads in 3.807 CPU sec, 3.624 real sec
# [M::process] read 148774 sequences (10000027 bp)...
# [M::mem_process_seqs] Processed 149012 reads in 3.369 CPU sec, 3.181 real sec
# [M::process] read 149164 sequences (10000118 bp)...
# [M::mem_process_seqs] Processed 148774 reads in 3.611 CPU sec, 3.258 real sec
# [M::process] read 149366 sequences (10000008 bp)...
# [M::mem_process_seqs] Processed 149164 reads in 3.911 CPU sec, 3.705 real sec
# [M::process] read 149438 sequences (10000123 bp)...
# [M::mem_process_seqs] Processed 149366 reads in 3.469 CPU sec, 3.205 real sec
# [M::process] read 149554 sequences (10000100 bp)...
# [M::mem_process_seqs] Processed 149438 reads in 4.437 CPU sec, 4.240 real sec
# [M::process] read 149570 sequences (10000035 bp)...
# [M::mem_process_seqs] Processed 149554 reads in 3.713 CPU sec, 3.488 real sec
# [M::process] read 149354 sequences (10000092 bp)...
# [M::mem_process_seqs] Processed 149570 reads in 4.046 CPU sec, 3.806 real sec
# [M::process] read 149208 sequences (10000061 bp)...
# [M::mem_process_seqs] Processed 149354 reads in 3.875 CPU sec, 3.652 real sec
# [M::process] read 148748 sequences (10000141 bp)...
# [M::mem_process_seqs] Processed 149208 reads in 4.108 CPU sec, 3.850 real sec
# [M::process] read 149100 sequences (10000094 bp)...
# [M::mem_process_seqs] Processed 148748 reads in 3.477 CPU sec, 3.250 real sec
# [M::process] read 149512 sequences (10000071 bp)...
# [M::mem_process_seqs] Processed 149100 reads in 3.640 CPU sec, 3.252 real sec
# [M::process] read 149638 sequences (10000137 bp)...
# [M::mem_process_seqs] Processed 149512 reads in 3.541 CPU sec, 3.256 real sec
# [M::process] read 149520 sequences (10000081 bp)...
# [M::mem_process_seqs] Processed 149638 reads in 3.498 CPU sec, 3.279 real sec
# [M::process] read 149370 sequences (10000082 bp)...
# [M::mem_process_seqs] Processed 149520 reads in 3.634 CPU sec, 3.239 real sec
# [M::process] read 149182 sequences (10000129 bp)...
# [M::mem_process_seqs] Processed 149370 reads in 3.600 CPU sec, 3.306 real sec
# [M::process] read 149042 sequences (10000047 bp)...
# [M::mem_process_seqs] Processed 149182 reads in 4.050 CPU sec, 3.712 real sec
# [M::process] read 148342 sequences (10000037 bp)...
# [M::mem_process_seqs] Processed 149042 reads in 4.146 CPU sec, 3.812 real sec
# [M::process] read 149354 sequences (10000015 bp)...
# [M::mem_process_seqs] Processed 148342 reads in 3.831 CPU sec, 3.465 real sec
# [M::process] read 149382 sequences (10000140 bp)...
# [M::mem_process_seqs] Processed 149354 reads in 3.827 CPU sec, 3.592 real sec
# [M::process] read 149518 sequences (10000063 bp)...
# [M::mem_process_seqs] Processed 149382 reads in 3.419 CPU sec, 3.198 real sec
# [M::process] read 149498 sequences (10000102 bp)...
# [M::mem_process_seqs] Processed 149518 reads in 3.565 CPU sec, 3.251 real sec
# [M::process] read 149232 sequences (10000006 bp)...
# [M::mem_process_seqs] Processed 149498 reads in 3.508 CPU sec, 3.226 real sec
# [M::process] read 149090 sequences (10000052 bp)...
# [M::mem_process_seqs] Processed 149232 reads in 3.758 CPU sec, 3.451 real sec
# [M::process] read 149066 sequences (10000069 bp)...
# [M::mem_process_seqs] Processed 149090 reads in 3.744 CPU sec, 3.524 real sec
# [M::process] read 149240 sequences (10000130 bp)...
# [M::mem_process_seqs] Processed 149066 reads in 3.981 CPU sec, 3.653 real sec
# [M::process] read 149490 sequences (10000034 bp)...
# [M::mem_process_seqs] Processed 149240 reads in 3.705 CPU sec, 3.454 real sec
# [M::process] read 149276 sequences (10000133 bp)...
# [M::mem_process_seqs] Processed 149490 reads in 3.584 CPU sec, 3.353 real sec
# [M::process] read 149470 sequences (10000079 bp)...
# [M::mem_process_seqs] Processed 149276 reads in 3.398 CPU sec, 3.179 real sec
# [M::process] read 149264 sequences (10000065 bp)...
# [M::mem_process_seqs] Processed 149470 reads in 3.717 CPU sec, 3.527 real sec
# [M::process] read 148982 sequences (10000063 bp)...
# [M::mem_process_seqs] Processed 149264 reads in 4.049 CPU sec, 3.718 real sec
# [M::process] read 148418 sequences (10000019 bp)...
# [M::mem_process_seqs] Processed 148982 reads in 3.547 CPU sec, 3.297 real sec
# [M::process] read 149140 sequences (10000087 bp)...
# [M::mem_process_seqs] Processed 148418 reads in 3.468 CPU sec, 3.204 real sec
# [M::process] read 149346 sequences (10000043 bp)...
# [M::mem_process_seqs] Processed 149140 reads in 3.412 CPU sec, 3.183 real sec
# [M::process] read 149524 sequences (10000141 bp)...
# [M::mem_process_seqs] Processed 149346 reads in 3.633 CPU sec, 3.250 real sec
# [M::process] read 149472 sequences (10000049 bp)...
# [M::mem_process_seqs] Processed 149524 reads in 3.516 CPU sec, 3.210 real sec
# [M::process] read 149406 sequences (10000121 bp)...
# [M::mem_process_seqs] Processed 149472 reads in 3.474 CPU sec, 3.228 real sec
# [M::process] read 149024 sequences (10000049 bp)...
# [M::mem_process_seqs] Processed 149406 reads in 3.608 CPU sec, 3.329 real sec
# [M::process] read 148412 sequences (10000017 bp)...
# [M::mem_process_seqs] Processed 149024 reads in 3.835 CPU sec, 3.649 real sec
# [M::process] read 149068 sequences (10000112 bp)...
# [M::mem_process_seqs] Processed 148412 reads in 3.453 CPU sec, 3.205 real sec
# [M::process] read 149312 sequences (10000010 bp)...
# [M::mem_process_seqs] Processed 149068 reads in 3.562 CPU sec, 3.245 real sec
# [M::process] read 149318 sequences (10000094 bp)...
# [M::mem_process_seqs] Processed 149312 reads in 3.523 CPU sec, 3.222 real sec
# [M::process] read 149532 sequences (10000014 bp)...
# [M::mem_process_seqs] Processed 149318 reads in 3.736 CPU sec, 3.356 real sec
# [M::process] read 149412 sequences (10000071 bp)...
# [M::mem_process_seqs] Processed 149532 reads in 3.660 CPU sec, 3.255 real sec
# [M::process] read 149100 sequences (10000080 bp)...
# [M::mem_process_seqs] Processed 149412 reads in 3.489 CPU sec, 3.200 real sec
# [M::process] read 148612 sequences (10000043 bp)...
# [M::mem_process_seqs] Processed 149100 reads in 3.456 CPU sec, 3.208 real sec
# [M::process] read 148524 sequences (10000082 bp)...
# [M::mem_process_seqs] Processed 148612 reads in 3.728 CPU sec, 3.424 real sec
# [M::process] read 149364 sequences (10000122 bp)...
# [M::mem_process_seqs] Processed 148524 reads in 3.633 CPU sec, 3.355 real sec
# [M::process] read 149374 sequences (10000006 bp)...
# [M::mem_process_seqs] Processed 149364 reads in 3.605 CPU sec, 3.272 real sec
# [M::process] read 149630 sequences (10000072 bp)...
# [M::mem_process_seqs] Processed 149374 reads in 3.613 CPU sec, 3.288 real sec
# [M::process] read 149550 sequences (10000024 bp)...
# [M::mem_process_seqs] Processed 149630 reads in 3.706 CPU sec, 3.299 real sec
# [M::process] read 149318 sequences (10000042 bp)...
# [M::mem_process_seqs] Processed 149550 reads in 3.522 CPU sec, 3.217 real sec
# [M::process] read 149156 sequences (10000029 bp)...
# [M::mem_process_seqs] Processed 149318 reads in 3.598 CPU sec, 3.346 real sec
# [M::process] read 148686 sequences (10000084 bp)...
# [M::mem_process_seqs] Processed 149156 reads in 3.793 CPU sec, 3.586 real sec
# [M::process] read 149404 sequences (10000087 bp)...
# [M::mem_process_seqs] Processed 148686 reads in 3.505 CPU sec, 3.231 real sec
# [M::process] read 149434 sequences (10000095 bp)...
# [M::mem_process_seqs] Processed 149404 reads in 3.650 CPU sec, 3.451 real sec
# [M::process] read 149546 sequences (10000063 bp)...
# [M::mem_process_seqs] Processed 149434 reads in 3.411 CPU sec, 3.213 real sec
# [M::process] read 149532 sequences (10000056 bp)...
# [M::mem_process_seqs] Processed 149546 reads in 3.544 CPU sec, 3.215 real sec
# [M::process] read 149514 sequences (10000144 bp)...
# [M::mem_process_seqs] Processed 149532 reads in 3.793 CPU sec, 3.408 real sec
# [M::process] read 149428 sequences (10000037 bp)...
# [M::mem_process_seqs] Processed 149514 reads in 3.731 CPU sec, 3.415 real sec
# [M::process] read 148684 sequences (10000012 bp)...
# [M::mem_process_seqs] Processed 149428 reads in 4.129 CPU sec, 3.851 real sec
# [M::process] read 149118 sequences (10000092 bp)...
# [M::mem_process_seqs] Processed 148684 reads in 3.920 CPU sec, 3.683 real sec
# [M::process] read 149376 sequences (10000100 bp)...
# [M::mem_process_seqs] Processed 149118 reads in 3.729 CPU sec, 3.395 real sec
# [M::process] read 149532 sequences (10000108 bp)...
# [M::mem_process_seqs] Processed 149376 reads in 3.735 CPU sec, 3.440 real sec
# [M::process] read 149486 sequences (10000097 bp)...
# [M::mem_process_seqs] Processed 149532 reads in 3.481 CPU sec, 3.261 real sec
# [M::process] read 149506 sequences (10000069 bp)...
# [M::mem_process_seqs] Processed 149486 reads in 3.655 CPU sec, 3.266 real sec
# [M::process] read 149316 sequences (10000082 bp)...
# [M::mem_process_seqs] Processed 149506 reads in 3.830 CPU sec, 3.638 real sec
# [M::process] read 149076 sequences (10000038 bp)...
# [M::mem_process_seqs] Processed 149316 reads in 3.526 CPU sec, 3.266 real sec
# [M::process] read 148772 sequences (10000040 bp)...
# [M::mem_process_seqs] Processed 149076 reads in 3.732 CPU sec, 3.526 real sec
# [M::process] read 149402 sequences (10000092 bp)...
# [M::mem_process_seqs] Processed 148772 reads in 3.751 CPU sec, 3.356 real sec
# [M::process] read 149254 sequences (10000115 bp)...
# [M::mem_process_seqs] Processed 149402 reads in 4.008 CPU sec, 3.692 real sec
# [M::process] read 149418 sequences (10000086 bp)...
# [M::mem_process_seqs] Processed 149254 reads in 3.562 CPU sec, 3.223 real sec
# [M::process] read 149478 sequences (10000008 bp)...
# [M::mem_process_seqs] Processed 149418 reads in 3.395 CPU sec, 3.161 real sec
# [M::process] read 148104 sequences (10000033 bp)...
# [M::mem_process_seqs] Processed 149478 reads in 4.274 CPU sec, 4.039 real sec
# [M::process] read 148972 sequences (10000046 bp)...
# [M::mem_process_seqs] Processed 148104 reads in 4.048 CPU sec, 3.793 real sec
# [M::process] read 149400 sequences (10000050 bp)...
# [M::mem_process_seqs] Processed 148972 reads in 3.533 CPU sec, 3.246 real sec
# [M::process] read 149308 sequences (10000089 bp)...
# [M::mem_process_seqs] Processed 149400 reads in 4.370 CPU sec, 4.098 real sec
# [M::process] read 149174 sequences (10000103 bp)...
# [M::mem_process_seqs] Processed 149308 reads in 3.388 CPU sec, 3.216 real sec
# [M::process] read 149328 sequences (10000108 bp)...
# [M::mem_process_seqs] Processed 149174 reads in 3.841 CPU sec, 3.570 real sec
# [M::process] read 149488 sequences (10000075 bp)...
# [M::mem_process_seqs] Processed 149328 reads in 3.822 CPU sec, 3.562 real sec
# [M::process] read 148204 sequences (10000090 bp)...
# [M::mem_process_seqs] Processed 149488 reads in 3.988 CPU sec, 3.726 real sec
# [M::process] read 148844 sequences (10000139 bp)...
# [M::mem_process_seqs] Processed 148204 reads in 3.681 CPU sec, 3.456 real sec
# [M::process] read 149092 sequences (10000036 bp)...
# [M::mem_process_seqs] Processed 148844 reads in 3.685 CPU sec, 3.471 real sec
# [M::process] read 149302 sequences (10000067 bp)...
# [M::mem_process_seqs] Processed 149092 reads in 3.805 CPU sec, 3.544 real sec
# [M::process] read 149240 sequences (10000099 bp)...
# [M::mem_process_seqs] Processed 149302 reads in 4.072 CPU sec, 3.751 real sec
# [M::process] read 149408 sequences (10000098 bp)...
# [M::mem_process_seqs] Processed 149240 reads in 3.521 CPU sec, 3.267 real sec
# [M::process] read 149402 sequences (10000027 bp)...
# [M::mem_process_seqs] Processed 149408 reads in 3.887 CPU sec, 3.657 real sec
# [M::process] read 149034 sequences (10000015 bp)...
# [M::mem_process_seqs] Processed 149402 reads in 3.632 CPU sec, 3.443 real sec
# [M::process] read 148724 sequences (10000057 bp)...
# [M::mem_process_seqs] Processed 149034 reads in 3.447 CPU sec, 3.146 real sec
# [M::process] read 149118 sequences (10000087 bp)...
# [M::mem_process_seqs] Processed 148724 reads in 4.164 CPU sec, 3.844 real sec
# [M::process] read 149308 sequences (10000063 bp)...
# [M::mem_process_seqs] Processed 149118 reads in 3.940 CPU sec, 3.654 real sec
# [M::process] read 149330 sequences (10000091 bp)...
# [M::mem_process_seqs] Processed 149308 reads in 3.625 CPU sec, 3.349 real sec
# [M::process] read 149394 sequences (10000098 bp)...
# [M::mem_process_seqs] Processed 149330 reads in 3.833 CPU sec, 3.585 real sec
# [M::process] read 149730 sequences (10000121 bp)...
# [M::mem_process_seqs] Processed 149394 reads in 4.424 CPU sec, 4.151 real sec
# [M::process] read 149552 sequences (10000104 bp)...
# [M::mem_process_seqs] Processed 149730 reads in 3.736 CPU sec, 3.533 real sec
# [M::process] read 148782 sequences (10000002 bp)...
# [M::mem_process_seqs] Processed 149552 reads in 3.841 CPU sec, 3.584 real sec
# [M::process] read 149434 sequences (10000103 bp)...
# [M::mem_process_seqs] Processed 148782 reads in 3.871 CPU sec, 3.494 real sec
# [M::process] read 149388 sequences (10000033 bp)...
# [M::mem_process_seqs] Processed 149434 reads in 3.470 CPU sec, 3.212 real sec
# [M::process] read 149388 sequences (10000020 bp)...
# [M::mem_process_seqs] Processed 149388 reads in 4.150 CPU sec, 3.966 real sec
# [M::process] read 149270 sequences (10000005 bp)...
# [M::mem_process_seqs] Processed 149388 reads in 3.952 CPU sec, 3.642 real sec
# [M::process] read 149290 sequences (10000018 bp)...
# [M::mem_process_seqs] Processed 149270 reads in 3.532 CPU sec, 3.280 real sec
# [M::process] read 149440 sequences (10000011 bp)...
# [M::mem_process_seqs] Processed 149290 reads in 3.486 CPU sec, 3.203 real sec
# [M::process] read 148498 sequences (10000115 bp)...
# [M::mem_process_seqs] Processed 149440 reads in 3.583 CPU sec, 3.278 real sec
# [M::process] read 149108 sequences (10000079 bp)...
# [M::mem_process_seqs] Processed 148498 reads in 3.461 CPU sec, 3.207 real sec
# [M::process] read 149560 sequences (10000000 bp)...
# [M::mem_process_seqs] Processed 149108 reads in 3.557 CPU sec, 3.224 real sec
# [M::process] read 149278 sequences (10000069 bp)...
# [M::mem_process_seqs] Processed 149560 reads in 3.533 CPU sec, 3.305 real sec
# [M::process] read 149262 sequences (10000062 bp)...
# [M::mem_process_seqs] Processed 149278 reads in 3.947 CPU sec, 3.610 real sec
# [M::process] read 149310 sequences (10000002 bp)...
# [M::mem_process_seqs] Processed 149262 reads in 4.099 CPU sec, 3.890 real sec
# [M::process] read 149424 sequences (10000022 bp)...
# [M::mem_process_seqs] Processed 149310 reads in 4.036 CPU sec, 3.721 real sec
# [M::process] read 149306 sequences (10000047 bp)...
# [M::mem_process_seqs] Processed 149424 reads in 3.609 CPU sec, 3.263 real sec
# [M::process] read 148378 sequences (10000036 bp)...
# [M::mem_process_seqs] Processed 149306 reads in 3.710 CPU sec, 3.316 real sec
# [M::process] read 149238 sequences (10000037 bp)...
# [M::mem_process_seqs] Processed 148378 reads in 3.543 CPU sec, 3.274 real sec
# [M::process] read 149318 sequences (10000086 bp)...
# [M::mem_process_seqs] Processed 149238 reads in 3.803 CPU sec, 3.517 real sec
# [M::process] read 149190 sequences (10000072 bp)...
# [M::mem_process_seqs] Processed 149318 reads in 3.917 CPU sec, 3.678 real sec
# [M::process] read 148234 sequences (10000042 bp)...
# [M::mem_process_seqs] Processed 149190 reads in 3.492 CPU sec, 3.279 real sec
# [M::process] read 149542 sequences (10000098 bp)...
# [M::mem_process_seqs] Processed 148234 reads in 4.036 CPU sec, 3.811 real sec
# [M::process] read 149528 sequences (10000040 bp)...
# [M::mem_process_seqs] Processed 149542 reads in 3.480 CPU sec, 3.249 real sec
# [M::process] read 149256 sequences (10000104 bp)...
# [M::mem_process_seqs] Processed 149528 reads in 3.588 CPU sec, 3.248 real sec
# [M::process] read 149226 sequences (10000001 bp)...
# [M::mem_process_seqs] Processed 149256 reads in 3.601 CPU sec, 3.428 real sec
# [M::process] read 149344 sequences (10000061 bp)...
# [M::mem_process_seqs] Processed 149226 reads in 3.765 CPU sec, 3.443 real sec
# [M::process] read 149278 sequences (10000133 bp)...
# [M::mem_process_seqs] Processed 149344 reads in 3.939 CPU sec, 3.628 real sec
# [M::process] read 148892 sequences (10000091 bp)...
# [M::mem_process_seqs] Processed 149278 reads in 3.573 CPU sec, 3.237 real sec
# [M::process] read 148778 sequences (10000071 bp)...
# [M::mem_process_seqs] Processed 148892 reads in 3.529 CPU sec, 3.236 real sec
# [M::process] read 149346 sequences (10000024 bp)...
# [M::mem_process_seqs] Processed 148778 reads in 3.861 CPU sec, 3.663 real sec
# [M::process] read 149458 sequences (10000057 bp)...
# [M::mem_process_seqs] Processed 149346 reads in 3.722 CPU sec, 3.340 real sec
# [M::process] read 149286 sequences (10000037 bp)...
# [M::mem_process_seqs] Processed 149458 reads in 3.613 CPU sec, 3.237 real sec
# [M::process] read 149344 sequences (10000115 bp)...
# [M::mem_process_seqs] Processed 149286 reads in 4.011 CPU sec, 3.745 real sec
# [M::process] read 149364 sequences (10000106 bp)...
# [M::mem_process_seqs] Processed 149344 reads in 3.439 CPU sec, 3.223 real sec
# [M::process] read 148958 sequences (10000123 bp)...
# [M::mem_process_seqs] Processed 149364 reads in 3.853 CPU sec, 3.613 real sec
# [M::process] read 148798 sequences (10000002 bp)...
# [M::mem_process_seqs] Processed 148958 reads in 3.442 CPU sec, 3.202 real sec
# [M::process] read 149458 sequences (10000118 bp)...
# [M::mem_process_seqs] Processed 148798 reads in 4.034 CPU sec, 3.732 real sec
# [M::process] read 149552 sequences (10000111 bp)...
# [M::mem_process_seqs] Processed 149458 reads in 3.645 CPU sec, 3.374 real sec
# [M::process] read 149332 sequences (10000012 bp)...
# [M::mem_process_seqs] Processed 149552 reads in 3.909 CPU sec, 3.681 real sec
# [M::process] read 149328 sequences (10000057 bp)...
# [M::mem_process_seqs] Processed 149332 reads in 3.609 CPU sec, 3.237 real sec
# [M::process] read 149272 sequences (10000077 bp)...
# [M::mem_process_seqs] Processed 149328 reads in 3.406 CPU sec, 3.174 real sec
# [M::process] read 148872 sequences (10000030 bp)...
# [M::mem_process_seqs] Processed 149272 reads in 3.584 CPU sec, 3.251 real sec
# [M::process] read 147812 sequences (10000066 bp)...
# [M::mem_process_seqs] Processed 148872 reads in 3.674 CPU sec, 3.476 real sec
# [M::process] read 149628 sequences (10000062 bp)...
# [M::mem_process_seqs] Processed 147812 reads in 3.838 CPU sec, 3.633 real sec
# [M::process] read 149672 sequences (10000046 bp)...
# [M::mem_process_seqs] Processed 149628 reads in 3.849 CPU sec, 3.585 real sec
# [M::process] read 149410 sequences (10000089 bp)...
# [M::mem_process_seqs] Processed 149672 reads in 3.556 CPU sec, 3.245 real sec
# [M::process] read 149398 sequences (10000122 bp)...
# [M::mem_process_seqs] Processed 149410 reads in 4.112 CPU sec, 3.800 real sec
# [M::process] read 149676 sequences (10000142 bp)...
# [M::mem_process_seqs] Processed 149398 reads in 3.662 CPU sec, 3.237 real sec
# [M::process] read 149482 sequences (10000104 bp)...
# [M::mem_process_seqs] Processed 149676 reads in 3.920 CPU sec, 3.749 real sec
# [M::process] read 149196 sequences (10000084 bp)...
# [M::mem_process_seqs] Processed 149482 reads in 3.723 CPU sec, 3.282 real sec
# [M::process] read 149544 sequences (10000055 bp)...
# [M::mem_process_seqs] Processed 149196 reads in 4.521 CPU sec, 4.153 real sec
# [M::process] read 149438 sequences (10000049 bp)...
# [M::mem_process_seqs] Processed 149544 reads in 3.854 CPU sec, 3.629 real sec
# [M::process] read 149528 sequences (10000084 bp)...
# [M::mem_process_seqs] Processed 149438 reads in 3.888 CPU sec, 3.658 real sec
# [M::process] read 149280 sequences (10000135 bp)...
# [M::mem_process_seqs] Processed 149528 reads in 3.615 CPU sec, 3.273 real sec
# [M::process] read 149524 sequences (10000101 bp)...
# [M::mem_process_seqs] Processed 149280 reads in 3.351 CPU sec, 3.176 real sec
# [M::process] read 149768 sequences (10000039 bp)...
# [M::mem_process_seqs] Processed 149524 reads in 3.581 CPU sec, 3.225 real sec
# [M::process] read 149436 sequences (10000078 bp)...
# [M::mem_process_seqs] Processed 149768 reads in 3.506 CPU sec, 3.309 real sec
# [M::process] read 149472 sequences (10000096 bp)...
# [M::mem_process_seqs] Processed 149436 reads in 3.800 CPU sec, 3.517 real sec
# [M::process] read 149664 sequences (10000068 bp)...
# [M::mem_process_seqs] Processed 149472 reads in 3.333 CPU sec, 3.142 real sec
# [M::process] read 149586 sequences (10000003 bp)...
# [M::mem_process_seqs] Processed 149664 reads in 3.524 CPU sec, 3.209 real sec
# [M::process] read 149472 sequences (10000104 bp)...
# [M::mem_process_seqs] Processed 149586 reads in 3.288 CPU sec, 3.115 real sec
# [M::process] read 149494 sequences (10000131 bp)...
# [M::mem_process_seqs] Processed 149472 reads in 3.466 CPU sec, 3.208 real sec
# [M::process] read 62046 sequences (4150097 bp)...
# [M::mem_process_seqs] Processed 149494 reads in 3.576 CPU sec, 3.460 real sec
# [M::mem_process_seqs] Processed 62046 reads in 1.537 CPU sec, 1.380 real sec
# [main] Version: 0.7.15-r1140
# [main] CMD: /opt/tools/bwa-0.7.15 mem -a /home/senne/nanopore/SNP/known_SNP_sequence/SNP_sequence.fasta /home/senne/nanopore/Multiplex/Reference_sequences/SNP/9948_Illumina_0.5µM/48.fasta
# [main] Real time: 605.663 sec; CPU: 653.864 sec

# %% [markdown]
# ##Sorting SAM file and converting to BAM

# %%
# !{samtools} view -Sbu {resultDir}/48.sam | {samtools} sort -o {resultDir}/48.bam -
# !{samtools} index {resultDir}/48.bam {resultDir}/48.bam.bai
print('Done')
# Out:
# [bam_sort_core] merging from 11 files...
# Done

# %% [markdown]
# ## Extracting SNP profile
# 1) Creating a vcf file
#
# 2) SNP profile generation

# %%
# Generate vcf file from bam file. Needs the reference and its index file 
#
# Note: the commands below are for samtools and bcftools v1.3.1 (will not work on v0.1.19!)

# Reporting all positions
# !{samtools} mpileup -d 1000000 -uf {snpFile} {resultDir}/48.bam | {bcftools} call -V indels -m - > {resultDir}/48.bam.vcf

# Reporting variants only (excludes SNPs homozygous for reference allele)
#!{samtools} mpileup -d 100000 -uf {snpFile} {resultDir}/test_sorted.bam | {bcftools} call -V indels -mv - > {resultDir}/test_sorted.bam.vcf

print('Done')
# Out:
# [mpileup] 1 samples in 1 input files
# Note: Neither --ploidy nor --ploidy-file given, assuming all sites are diploid
# Done

# %%
# Get SNP profile


snpData = {}

with open(resultDir+'/48.bam.vcf') as f:
    for l in f:
        if l.startswith('#'):
            continue
            
        snp, pos, id, ref, alt, qual, filter, info, d, dd = l.split()
        
        # Our SNP of interest is always at position 26 of the reference
        if int(pos) != 26:
            continue

        par = {}
        for p in info.split(';'):
            pv = p.split('=')
            par[pv[0]] = pv[1]
        
        snpData[snp] = {'pos': pos, 'ref': ref, 'alt': alt, 'qual': qual, 'filter': filter, 'info': par}

# DEBUG
print('Got data for {} SNPs:'.format(len(snpData)))

# Save/print results
with open(resultDir + '/ttt_profile.csv', 'w') as f:
    # Table header
    f.write('snp, coverage, ref_allele, ref_percent, alt_allele, alt_percent, genotype\n')
    
    # Table data
    for s in sorted(snpData.keys()):
        totalDepth = int(snpData[s]['info']['DP'])
        depthList  = [int(d) for d in snpData[s]['info']['DP4'].split(',')]
        refDepth   = sum(depthList[0:2])
        altDepth   = sum(depthList[2:4])
        
        # Estimate the diploid genotype: when the minor allele is more than 10 times weaker than the major allele,
        # we should ignore it for a pure sample?
        if refDepth > altDepth and altDepth/refDepth < 0.1:
            genotype = snpData[s]['ref'] + snpData[s]['ref']
        elif altDepth > refDepth and refDepth/altDepth < 0.1:
            genotype = snpData[s]['alt'] + snpData[s]['alt']
        else:
            genotype = snpData[s]['ref'] + snpData[s]['alt']
        
        if snpData[s]['alt'] == '.':
            # Only 1 allele was observed
            f.write(','.join([s, str(totalDepth), snpData[s]['ref'], '{:.1f}'.format(100*refDepth/totalDepth), '', '', snpData[s]['ref']+snpData[s]['ref']]) + '\n')
            # DEBUG
            print('  {} ({})  {} ({:.1f} %)'.format(s, totalDepth, snpData[s]['ref'], 100*refDepth/totalDepth))
        else:
            # Two alleles were observed
            f.write(','.join([s, str(totalDepth), snpData[s]['ref'], '{:.1f}'.format(100*refDepth/totalDepth), snpData[s]['alt'], '{:.1f}'.format(100*altDepth/totalDepth), genotype]) + '\n')
            # DEBUG
            print('  {} ({})  {} ({:.1f} %)  {} ({:.1f} %)'.format(s, totalDepth, snpData[s]['ref'], 100*refDepth/totalDepth, snpData[s]['alt'], 100*altDepth/totalDepth))
# Out:
# Got data for 52 SNPs:
#   rs1005533 (144996)  A (99.8 %)
#   rs1015250 (248717)  C (0.0 %)  G (100.0 %)
#   rs1024116 (402530)  A (43.0 %)  G (57.0 %)
#   rs1028528 (128801)  A (69.1 %)  G (30.9 %)
#   rs1029047 (79115)  A (99.7 %)
#   rs1031825 (277887)  A (50.5 %)  C (49.5 %)
#   rs10495407 (1000011)  A (50.1 %)  G (49.9 %)
#   rs1335873 (299477)  A (0.1 %)  T (99.9 %)
#   rs1355366 (656223)  A (51.9 %)  G (48.1 %)
#   rs1357617 (345388)  A (99.6 %)
#   rs1360288 (30642)  C (71.1 %)  T (28.9 %)
#   rs1382387 (189198)  G (52.6 %)  T (47.4 %)
#   rs1413212 (998999)  A (0.1 %)  G (99.9 %)
#   rs1454361 (804990)  A (53.3 %)  T (46.7 %)
#   rs1463729 (226122)  A (0.1 %)  G (99.9 %)
#   rs1490413 (202631)  A (0.2 %)  G (99.8 %)
#   rs1493232 (999987)  A (99.7 %)
#   rs1528460 (8310)  C (0.2 %)  T (99.8 %)
#   rs1886510 (114319)  C (54.4 %)  T (45.6 %)
#   rs1979255 (88400)  C (99.8 %)
#   rs2016276 (246601)  A (46.5 %)  G (53.5 %)
#   rs2040411 (93944)  A (99.8 %)
#   rs2046361 (152422)  A (0.1 %)  T (99.9 %)
#   rs2056277 (232780)  C (0.2 %)  T (99.8 %)
#   rs2076848 (91942)  A (99.7 %)
#   rs2107612 (51093)  A (99.8 %)
#   rs2111980 (999992)  A (99.7 %)
#   rs251934 (261745)  C (50.6 %)  T (49.4 %)
#   rs2830795 (709699)  A (99.6 %)
#   rs2831700 (92936)  A (99.8 %)
#   rs354439 (175341)  A (51.3 %)  T (48.7 %)
#   rs717302 (602923)  A (45.9 %)  G (54.1 %)
#   rs719366 (865997)  C (51.8 %)  T (48.2 %)
#   rs722098 (92890)  A (99.7 %)
#   rs727811 (871011)  A (99.7 %)
#   rs729172 (560432)  A (99.6 %)
#   rs733164 (108275)  A (0.1 %)  G (99.9 %)
#   rs735155 (57595)  A (49.7 %)  G (50.3 %)
#   rs737681 (247808)  C (99.8 %)
#   rs740910 (468156)  A (47.2 %)  G (52.8 %)
#   rs763869 (48673)  C (54.4 %)  T (45.6 %)
#   rs8037429 (28407)  C (0.3 %)  T (99.7 %)
#   rs826472 (29535)  C (55.5 %)  T (44.5 %)
#   rs873196 (172694)  C (53.1 %)  T (46.9 %)
#   rs876724 (110217)  C (63.4 %)  T (36.6 %)
#   rs891700 (25032)  A (0.1 %)  G (99.9 %)
#   rs901398 (1000021)  C (99.6 %)
#   rs907100 (187108)  C (50.0 %)  G (50.0 %)
#   rs914165 (647724)  A (0.1 %)  G (99.9 %)
#   rs917118 (328290)  C (53.5 %)  T (46.5 %)
#   rs938283 (460680)  C (99.8 %)
#   rs964681 (319420)  C (0.2 %)  T (99.8 %)
